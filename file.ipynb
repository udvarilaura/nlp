# %%
import pandas as pd
#training database
training = pd.read_json("train.json", orient='records') 
#testing database
testing = pd.read_json("test.json", orient='records')
dbs = pd.concat([training, testing]) ##databases concatenated

dbs.info()
dbs.hist()
dbs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 658515 entries, 0 to 131702
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   post    658515 non-null  object
#  1   age     658515 non-null  int64
#  2   gender  658515 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 20.1+ MB
#                                                 post  age  gender
# 0                          ooh shiny new commenting!   16  female
# 1  so wuts up? today i had the parade. suked. but...   14    male
# 2  i don't know about anyone else anymore, but i'...   24  female
# 3  urlLink    another roof-top sunset  Posted by ...   24    male
# 4  gawd i luv my nanny!  she's absolutely the gre...   23  female

# %%
post = dbs["post"]

post.head()
# Out:
# 0                            ooh shiny new commenting!
# 1    so wuts up? today i had the parade. suked. but...
# 2    i don't know about anyone else anymore, but i'...
# 3    urlLink    another roof-top sunset  Posted by ...
# 4    gawd i luv my nanny!  she's absolutely the gre...
# Name: post, dtype: object

# %%
## removing stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
import nltk

nltk.download("stopwords")
nltk.download('punkt')

stop_words = set(stopwords.words("english"))

post = post.apply(lambda row: row.lower())
post = post.apply(lambda row: " ".join([word for word in word_tokenize(row) if not word in stop_words and word.isalpha()]))

post.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\udvar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\udvar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-49816e4bb652> in <module>
#       9 stop_words = set(stopwords.words("english"))
#      10
# ---> 11 dbs = dbs.apply(lambda row: row.lower())
#      12 dbs = dbs.apply(lambda row: " ".join([word for word in word_tokenize(row) if not word in stop_words and word.isalpha()]))
#      13
#
# C:\Python39\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7763             kwds=kwds,
#    7764         )
# -> 7765         return op.get_result()
# ...

# %%
##stemming
from nltk.stem import PorterStemmer  

stemmer = PorterStemmer()

reviews = reviews.apply(stemmer.stem)

reviews.head()

# %%
##spacy - nem tudom mi ez
##ehhez promptban pip install spacy
import spacy
nlp = spacy.load('en')

reviews = reviews.apply()

# %%
##lemmatizálás
from nltk.stem import WordNetLemmatizer

wnlemmatizer = WordNetLemmatizer()

reviews = reviews.apply(lambda row: " ".join([wnlemmatizer.lemmatize(word) for word in word_tokenize(row)]))

reviews.head(n = 10)

# %%
rekorszam = len(reviews)
print(rekordszam)

train_sorok = int(round(rekordszam/2))
##val_sorok = (rekordszam - train_sorok) // 3
test_sorok = (rekordok - train_sorok)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-af53de55bc78> in <module>
# ----> 1 rekorszam = len(reviews)
#       2 print(rekordszam)
#       3
#       4 train_sorok = int(round(rekordszam/2))
#       5 val_sorok = (rekordszam - train_sorok) // 3
#
# NameError: name 'reviews' is not defined
